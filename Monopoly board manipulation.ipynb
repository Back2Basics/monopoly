# %%
import numpy as np
import pandas as pd
import json
from pathlib import Path

# %%
from IPython.display import Image
Image("Monopoly-Board.jpg", width=500, height=500)

# %%
board = pd.read_json(Path('board.json').read_text())
#board.columns = ['square',*board.columns[1:]]
#board.cost[pd.isnull(board.cost)]=0

# %%
board.index.name='square'
board.sort_index(inplace=True)

# %%
board
# Out:
#            color  cost  houses                   name owner  \
# square
# 0           None     0       0                     GO  None
# 1         purple    60       0     Mediterranean Ave.  None
# 2           None     0       0        Community Chest   gov
# 3         purple    80       0            Baltic Ave.  None
# 4           None     0       0             Income Tax   gov
# 5           None   200       0      Reading Railroad.  None
# 6       bluegrey   100       0          Oriental Ave.  None
# 7           None     0       0                 Chance   gov
# 8       bluegrey   100       0           Vermont Ave.  None
# 9       bluegrey   120       0        Conneticut Ave.  None
# 10          None     0       0                   Jail   gov
# 11        maroon   140       0        St. Charles Pl.  None
# 12          None   150       0       Electric Company  None
# 13        maroon   140       0            States Ave.  None
# ...

# %%
owner = board.owner.tolist()
houses = board.houses.tolist()

# %%
square = 1
[x,y for x,y in board.groupby('color') if x=board.color.iloc[square]]:
# Out:
#   File "<ipython-input-11-764d43b87a5a>", line 2
#     [x,y for x,y in board.groupby('color') if x=board.color.iloc[square]]:
#            ^
# SyntaxError: invalid syntax

# %%
def available_property_indexes():
    owned_properties = set(count for count,x in enumerate(owner) if x!=None)
    available_properties = set(board[(board.type=='property')].index) - owned_properties
    return available_properties
available_property_indexes()
# Out:
# {1,
#  3,
#  6,
#  8,
#  9,
#  11,
#  13,
#  14,
#  16,
#  18,
#  19,
#  21,
#  23,
#  24,
#  26,
#  27,
#  29,
#  31,
#  32,
#  34,
#  37,
#  39}

# %%
data = [365, 399, 399, 405,429,439,445,460, 475, 485, 512, 569, 575, 580, 595, 629, 899, 1125, 998]

# %%
def how_many_houses_can_be_bought_on_properties():
    
    return set()
